# %% [markdown]
# # Coding practice: an autoregressive model's sequence NLL
#
# An autoregressive model scores a sequence by the chain rule of probability: `p(x) = prod_t p(x_t | earlier tokens)`. Its negative log-likelihood sums the negative logs of those per-step probabilities. Fill in the TODO, run the cells, and enter the printed number.
#
# > Save your own copy first.

# %%
import math

# The conditional probability the model assigned to each observed token, in order.
conditional_probs = [0.5, 0.25, 0.5]

# %%
def sequence_nll(probs):
    """Return the negative log-likelihood of the sequence: sum of -log p_t."""
    total = 0.0
    for p in probs:
        # TODO: add the negative log of this step's conditional probability
        raise NotImplementedError("Add -log(p) for each step.")
    return total

# %%
print("sequence NLL =", round(sequence_nll(conditional_probs), 4))

# %% [markdown]
# The printed **sequence NLL** is your answer. Enter it in the check on the next page.
#
# Try it yourself: a model that assigned higher probabilities to the same tokens gets a lower NLL. That is exactly the training signal for an autoregressive model.
