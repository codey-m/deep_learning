# %% [markdown]
# # Coding practice: one round of message passing
#
# A graph neural network updates each node by **aggregating messages from its neighbors**. Here you implement one round of sum aggregation on a small fixed graph, then read off one node's new value.
#
# Nothing here is auto-graded in the notebook. Fill in the one TODO, run the cells, and enter the printed number for node 2 in the check on the course page.
#
# > **Save your own copy first:** File → Save a copy in Drive.

# %%
# Five nodes with scalar features, and each node's list of neighbors (undirected edges).
features = [1, 2, 3, 4, 5]
neighbors = {
    0: [1, 2],
    1: [0, 2],
    2: [0, 1, 3],
    3: [2, 4],
    4: [3],
}

# %%
def message_pass(features, neighbors):
    """Return each node's new feature: the SUM of its neighbors' current features."""
    new_features = []
    for node in range(len(features)):
        # TODO: sum the current features of this node's neighbors, and append the result.
        raise NotImplementedError("Aggregate the neighbor features for each node.")
    return new_features

# %%
updated = message_pass(features, neighbors)
print("updated features:", updated)
print("node 2 updated feature:", updated[2])

# %% [markdown]
# The number printed for **node 2** is your answer. Enter it in the check on the next page.
#
# Try it yourself: switch the aggregation from a sum to a mean, or add a self-loop (include the node's own feature in its sum). How does node 2 change, and why?
